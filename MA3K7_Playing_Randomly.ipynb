# %%
import numpy as np
import matplotlib.pyplot as plt
def game_random_fill(n):
    # For even n, ensure equal number of 0s and 1s; for odd n, one more of either 0 or 1
    total_elements = n * n
    if n % 2 == 0:  # Even n
        ones_count = total_elements // 2
    else:  # Odd n
        ones_count = total_elements // 2 + np.random.choice([0, 1])
    
    zeros_count = total_elements - ones_count
    
    # Create a flat array with the correct counts of 0s and 1s
    flat_matrix = np.array([1]*ones_count + [0]*zeros_count)
    
    # Shuffle the array to randomize 0 and 1 placements
    np.random.shuffle(flat_matrix)
    
    # Reshape the flat array back into an n x n matrix
    matrix = flat_matrix.reshape(n, n)
    
    # Calculate the determinant of the matrix
    det = np.linalg.det(matrix)
    
    return matrix, det

# %%
# Prepare data for plotting
n_values = list(range(1, 31))
probabilities = []

for n in n_values:
    determinant_zero_count_random = 0
    k = 10
    for i in range(k):
        i, det_random = game_random_fill(n)
        # print(i)
        if det_random == 0:
            determinant_zero_count_random += 1
    probability_determinant_is_zero = round((determinant_zero_count_random / k) * 100, 2)
    probabilities.append(probability_determinant_is_zero)
    
    print('probability of determinant equals to 0 for n =',n,':', probability_determinant_is_zero,'%')
# Out:
# probability of determinant equals to 0 for n = 1 : 50.0 %
# probability of determinant equals to 0 for n = 2 : 70.0 %
# probability of determinant equals to 0 for n = 3 : 60.0 %
# probability of determinant equals to 0 for n = 4 : 60.0 %
# probability of determinant equals to 0 for n = 5 : 30.0 %
# probability of determinant equals to 0 for n = 6 : 60.0 %
# probability of determinant equals to 0 for n = 7 : 40.0 %
# probability of determinant equals to 0 for n = 8 : 60.0 %
# probability of determinant equals to 0 for n = 9 : 10.0 %
# probability of determinant equals to 0 for n = 10 : 0.0 %
# probability of determinant equals to 0 for n = 11 : 0.0 %
# probability of determinant equals to 0 for n = 12 : 0.0 %
# probability of determinant equals to 0 for n = 13 : 10.0 %
# probability of determinant equals to 0 for n = 14 : 0.0 %
# probability of determinant equals to 0 for n = 15 : 0.0 %
# probability of determinant equals to 0 for n = 16 : 0.0 %
# probability of determinant equals to 0 for n = 17 : 0.0 %
# probability of determinant equals to 0 for n = 18 : 0.0 %
# probability of determinant equals to 0 for n = 19 : 0.0 %
# probability of determinant equals to 0 for n = 20 : 0.0 %
# probability of determinant equals to 0 for n = 21 : 0.0 %
# probability of determinant equals to 0 for n = 22 : 0.0 %
# probability of determinant equals to 0 for n = 23 : 0.0 %
# probability of determinant equals to 0 for n = 24 : 0.0 %
# probability of determinant equals to 0 for n = 25 : 0.0 %
# probability of determinant equals to 0 for n = 26 : 0.0 %
# probability of determinant equals to 0 for n = 27 : 0.0 %
# probability of determinant equals to 0 for n = 28 : 0.0 %
# probability of determinant equals to 0 for n = 29 : 0.0 %
# probability of determinant equals to 0 for n = 30 : 0.0 %

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(n_values, probabilities, marker='o', linestyle='-', color='b')
plt.title('Probability of Determinant Being Zero vs. Matrix Size n')
plt.xlabel('Matrix Size n')
plt.ylabel('Probability of Determinant Being Zero (%)')
plt.grid(True)
plt.xticks(n_values)
plt.show()

# %%
# Prepare data for plotting
n_values100 = list(range(1, 31))
probabilities100 = []

for n in n_values100:
    determinant_zero_count_random = 0
    k = 100
    for i in range(k):
        i, det_random = game_random_fill(n)
        # print(i)
        if det_random == 0:
            determinant_zero_count_random += 1
    probability_determinant_is_zero = round((determinant_zero_count_random / k) * 100, 2)
    probabilities100.append(probability_determinant_is_zero)
    
    print('probability of determinant equals to 0 for n =',n,':', probability_determinant_is_zero,'%')
# Out:
# probability of determinant equals to 0 for n = 1 : 47.0 %
# probability of determinant equals to 0 for n = 2 : 65.0 %
# probability of determinant equals to 0 for n = 3 : 54.0 %
# probability of determinant equals to 0 for n = 4 : 55.0 %
# probability of determinant equals to 0 for n = 5 : 51.0 %
# probability of determinant equals to 0 for n = 6 : 60.0 %
# probability of determinant equals to 0 for n = 7 : 49.0 %
# probability of determinant equals to 0 for n = 8 : 33.0 %
# probability of determinant equals to 0 for n = 9 : 34.0 %
# probability of determinant equals to 0 for n = 10 : 27.0 %
# probability of determinant equals to 0 for n = 11 : 15.0 %
# probability of determinant equals to 0 for n = 12 : 8.0 %
# probability of determinant equals to 0 for n = 13 : 7.0 %
# probability of determinant equals to 0 for n = 14 : 0.0 %
# probability of determinant equals to 0 for n = 15 : 2.0 %
# probability of determinant equals to 0 for n = 16 : 1.0 %
# probability of determinant equals to 0 for n = 17 : 0.0 %
# probability of determinant equals to 0 for n = 18 : 0.0 %
# probability of determinant equals to 0 for n = 19 : 0.0 %
# probability of determinant equals to 0 for n = 20 : 0.0 %
# probability of determinant equals to 0 for n = 21 : 0.0 %
# probability of determinant equals to 0 for n = 22 : 0.0 %
# probability of determinant equals to 0 for n = 23 : 0.0 %
# probability of determinant equals to 0 for n = 24 : 0.0 %
# probability of determinant equals to 0 for n = 25 : 0.0 %
# probability of determinant equals to 0 for n = 26 : 0.0 %
# probability of determinant equals to 0 for n = 27 : 0.0 %
# probability of determinant equals to 0 for n = 28 : 0.0 %
# probability of determinant equals to 0 for n = 29 : 0.0 %
# probability of determinant equals to 0 for n = 30 : 0.0 %

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(n_values100, probabilities100, marker='o', linestyle='-', color='b')
plt.title('Probability of Determinant Being Zero vs. Matrix Size n')
plt.xlabel('Matrix Size n')
plt.ylabel('Probability of Determinant Being Zero (%)')
plt.grid(True)
plt.xticks(n_values)
plt.show()

# %%
# Prepare data for plotting
n_values10000 = list(range(1, 31))
probabilities10000 = []

for n in n_values10000:
    determinant_zero_count_random = 0
    k = 10000
    for i in range(k):
        i, det_random = game_random_fill(n)
        # print(i)
        if det_random == 0:
            determinant_zero_count_random += 1
    probability_determinant_is_zero = round((determinant_zero_count_random / k) * 100, 2)
    probabilities10000.append(probability_determinant_is_zero)
    
    print('probability of determinant equals to 0 for n =',n,':', probability_determinant_is_zero,'%')
# Out:
# probability of determinant equals to 0 for n = 1 : 51.0 %
# probability of determinant equals to 0 for n = 2 : 66.78 %
# probability of determinant equals to 0 for n = 3 : 57.78 %
# probability of determinant equals to 0 for n = 4 : 58.86 %
# probability of determinant equals to 0 for n = 5 : 56.2 %
# probability of determinant equals to 0 for n = 6 : 54.12 %
# probability of determinant equals to 0 for n = 7 : 46.57 %
# probability of determinant equals to 0 for n = 8 : 41.19 %

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(n_values10000, probabilities10000, marker='o', linestyle='-', color='b')
plt.title('Probability of Determinant Being Zero vs. Matrix Size n')
plt.xlabel('Matrix Size n')
plt.ylabel('Probability of Determinant Being Zero (%)')
plt.grid(True)
plt.xticks(n_values)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(n_values, probabilities, marker='o', linestyle='-', color='b')
plt.plot(n_values100, probabilities100, marker='*', linestyle='-', color='g')
plt.plot(n_values10000, probabilities10000, marker='x', linestyle='-', color='r')
plt.title('Probability of Determinant Being Zero vs. Matrix Size n')
plt.xlabel('Matrix Size n')
plt.ylabel('Probability of Determinant Being Zero (%)')
plt.grid(True)
plt.xticks(n_values)
plt.show()
